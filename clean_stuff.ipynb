# %%
import pandas as pd
import json
import lib.mass_update as mu

mosaiq_hierarchy = r'C:\Users\falve11887\OneDrive - Elekta\Documents\Monthly Clean up automations\products_hierarchy\MOSAIQ.json'

all_data = pd.read_csv(r'C:\Users\falve11887\Downloads\all products.csv')

mosaiq = mu.filter_df_by_hierarchy_json(all_data, mosaiq_hierarchy)

mosaiq
# Out:
#                                              Sibex Name               Status  \
# 186                       DICOM RT Structure Set Import  Not in Clinical Use
# 207                               HP xw8600 Workstation  Not in Clinical Use
# 269                            Connectivity / Sequencer            Installed
# 272      Connectivity to DICOM RT Philips/ADAC Pinnacle            Installed
# 273         Connectivity to Elekta Agility 160 Leaf MLC            Installed
# ...                                                 ...                  ...
# 1314505                   DICOM RT Structure Set Import            Installed
# 1314506                   DICOM RT Structure Set Import            Installed
# 1314531                                          MOSAIQ            Installed
# 1314704                                          MOSAIQ            Installed
# 1314705                                 MOSAIQ Software            Installed
#
#          Quantity Version Detail  \
# 186           1.0         4.70.0
# 207           1.0         4.70.0
# 269           1.0            NaN
# 272           1.0            NaN
# 273           1.0            NaN
# ...           ...            ...
# 1314505       1.0            NaN
# 1314506       1.0            NaN
# 1314531       1.0            NaN
# 1314704       1.0            NaN
# 1314705       1.0        2.81.47
#
#                                  Parent: Installed Product  \
# 186                            XIO/10001-CMS1/40048583rtp1
# 207                            XIO/10001-CMS1/40048583rtp1
# 269           Radiation Oncology/10001-RO00/Non-Serialized
# 272      Connectivity / Sequencer/10001-RO00/Non-Serial...
# 273      Connectivity / Sequencer/10001-RO00/Non-Serial...
# ...                                                    ...
# 1314505                        XIO/98791-CMS1/60069075Demo
# 1314506                       XIO/98791-CMS1/60069075Demo1
# 1314531                                                NaN
# 1314704                                                NaN
# 1314705                   MOSAIQ/98806-RO01/Non-Serialized
#
#          Master Device: Installed Product  \
# 186           XIO/10001-CMS1/40048583rtp1
# 207           XIO/10001-CMS1/40048583rtp1
# 269      MOSAIQ/10001-RO00/Non-Serialized
# 272      MOSAIQ/10001-RO00/Non-Serialized
# 273      MOSAIQ/10001-RO00/Non-Serialized
# ...                                   ...
# 1314505       XIO/98791-CMS1/60069075Demo
# 1314506      XIO/98791-CMS1/60069075Demo1
# 1314531                               NaN
# 1314704                               NaN
# 1314705  MOSAIQ/98806-RO01/Non-Serialized
#
#         Order Line Item: Order Line Item Number Work Order: Work Order Number  \
# 186                                         NaN                           NaN
# 207                                         NaN                           NaN
# 269                                         NaN                           NaN
# 272                                  OL-1050270                           NaN
# 273                                  OL-3195859                           NaN
# ...                                         ...                           ...
# 1314505                                     NaN                           NaN
# 1314506                                     NaN                           NaN
# 1314531                                     NaN                           NaN
# 1314704                                     NaN                           NaN
# 1314705                                     NaN                           NaN
#
#                                          Installed Product  \
# 186      DICOM RT Structure Set Import/10001-CMS1/Non-S...
# 207            HP xw8600 Workstation/10001-CMS1/CZC8320ZK9
# 269      Connectivity / Sequencer/10001-RO00/Non-Serial...
# 272      Connectivity to DICOM RT Philips/ADAC Pinnacle...
# 273      Connectivity to Elekta Agility 160 Leaf MLC/10...
# ...                                                    ...
# 1314505  DICOM RT Structure Set Import/98791-CMS1/Non-S...
# 1314506  DICOM RT Structure Set Import/98791-CMS1/Non-S...
# 1314531                  MOSAIQ/98791-CMS1/For Affected IB
# 1314704                   MOSAIQ/98806-RO01/Non-Serialized
# 1314705                 MOSAIQ Software/98806-RO01/2.81.47
#
#         Installed Product ID  ... Movex Account Number  \
# 186          a0R32000005JElu  ...              10001.0
# 207          a0R32000005JEmF  ...              10001.0
# 269          a0R32000004rEeD  ...              10001.0
# 272          a0R32000003crl6  ...              10001.0
# 273          a0R6g00000HfISo  ...              10001.0
# ...                      ...  ...                  ...
# 1314505      a0R60000002SWt8  ...              98791.0
# 1314506      a0R60000002SWvR  ...              98791.0
# 1314531      a0R0d000006IwbG  ...              98791.0
# 1314704      a0R0d000006ELt4  ...              98806.0
# 1314705      a0R0d000006ELt9  ...              98806.0
#
#                       Location: Location Name Location Movex Id  \
# 186                        USLN 9 di Grosseto              CMS1
# 207                        USLN 9 di Grosseto              CMS1
# 269      MOSAIQ - Azienda USL N.9 Di Grosseto              RO00
# 272      MOSAIQ - Azienda USL N.9 Di Grosseto              RO00
# 273      MOSAIQ - Azienda USL N.9 Di Grosseto              RO00
# ...                                       ...               ...
# 1314505       Elekta Medical Systems - Brazil              CMS1
# 1314506       Elekta Medical Systems - Brazil              CMS1
# 1314531       Elekta Medical Systems - Brazil              CMS1
# 1314704                         Nucletron OIS              RO01
# 1314705                         Nucletron OIS              RO01
#
#                   Product: Product Name Product: Product Code Account Country  \
# 186       DICOM RT Structure Set Import         40503000000RO              IT
# 207               HP xw8600 Workstation         TPPLANRB438UT              IT
# 269              CONNECTIVITY/SEQUENCER         #CONNECTIVITY              IT
# 272      CONN TO DICOM RT PHIL ADAC/PIN       45014022001IQRO              IT
# 273      CONN ELEKTA AGILITY 160 LF MLC       45011003102IQRO              IT
# ...                                 ...                   ...             ...
# 1314505   DICOM RT Structure Set Import         40503000000RO              BR
# 1314506   DICOM RT Structure Set Import         40503000000RO              BR
# 1314531                          MOSAIQ               #MOSAIQ              BR
# 1314704                          MOSAIQ               #MOSAIQ              NL
# 1314705                 MOSAIQ SOFTWARE            #MOSAIQ_SW              NL
#
#         Account Region Region Customer/Device Acceptance Date  \
# 186                REU    REU                       7/14/2009
# 207                REU    REU                       7/14/2009
# 269                REU    REU                             NaN
# 272                REU    REU                       9/21/2016
# 273                REU    REU                       7/19/2024
# ...                ...    ...                             ...
# 1314505            RSA  RAMER                       9/22/2010
# 1314506            RSA  RAMER                       9/22/2010
# 1314531            RSA  RAMER                             NaN
# 1314704            REU    REU                        2/1/2019
# 1314705            REU    REU                        2/1/2019
#
#         Full Location Movex Id
# 186               10001_CMS1_2
# 207               10001_CMS1_2
# 269               10001_RO00_2
# 272               10001_RO00_2
# 273               10001_RO00_2
# ...                        ...
# 1314505           98791_CMS1_2
# 1314506           98791_CMS1_2
# 1314531           98791_CMS1_2
# 1314704           98806_RO01_2
# 1314705           98806_RO01_2
#
# [145290 rows x 21 columns]

# %%
with open(mosaiq_hierarchy, 'r', encoding='utf-8') as file:
    mosaiq_hierarchy_dict = json.load(file)

mosaiq_hierarchy_fix = mu.clean_product_hierarchy(mosaiq, mosaiq_hierarchy_dict, 'hierarchy_fix.xlsx')
