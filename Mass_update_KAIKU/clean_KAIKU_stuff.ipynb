# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

import pandas as pd
import json
import lib.mass_update as mu

kaiku_hierarchy = r'C:\Users\falve11887\OneDrive - Elekta\Documents\Monthly Clean up automations\products_hierarchy\KAIKU.json'

ib_tracked_df = pd.read_csv(r'C:\Users\falve11887\OneDrive - Elekta\Documents\Monthly Clean up automations\IB filter\IB tracked.csv')

all_data = pd.read_csv(r'C:\Users\falve11887\Downloads\all products.csv')

kaiku = mu.filter_df_by_hierarchy_json(all_data, kaiku_hierarchy)

with open(kaiku_hierarchy, 'r', encoding='utf-8') as file:
    kaiku_hierarchy_dict = json.load(file)

kaiku_hierarchy_fix = mu.clean_product_hierarchy(kaiku, kaiku_hierarchy_dict, 'mass_update_kaiku_hierarchy_fix.xlsx')

kaiku_quantity_fix = mu.clean_quantity(kaiku, 'mass_update_kaiku_quantity_fix.xlsx')

kaiku_sts_fix = mu.clean_status(kaiku, kaiku_hierarchy_dict, '2026-06-12', 'mass_update_kaiku_sts_fix.xlsx')
