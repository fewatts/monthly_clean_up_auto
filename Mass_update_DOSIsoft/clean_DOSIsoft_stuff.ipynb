# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

import pandas as pd
import json
import lib.mass_update as mu

DOSIsoft_hierarchy = r'C:\Users\falve11887\OneDrive - Elekta\Documents\Monthly Clean up automations\products_hierarchy\DOSIsoft.json'

ib_tracked_df = pd.read_csv(r'C:\Users\falve11887\OneDrive - Elekta\Documents\Monthly Clean up automations\IB filter\IB tracked.csv')

all_data = pd.read_csv(r'C:\Users\falve11887\Downloads\all products.csv')

DOSIsoft = mu.filter_df_by_hierarchy_json(all_data, DOSIsoft_hierarchy)

with open(DOSIsoft_hierarchy, 'r', encoding='utf-8') as file:
    DOSIsoft_hierarchy_dict = json.load(file)

DOSIsoft_hierarchy_fix = mu.clean_product_hierarchy(DOSIsoft, DOSIsoft_hierarchy_dict, 'mass_update_DOSIsoft_hierarchy_fix.xlsx')
