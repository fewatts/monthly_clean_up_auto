# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))
import pandas as pd
import lib.manual as mu

# Carrega seus arquivos brutos
all_data_df = pd.read_csv(r'C:\Users\falve11887\Downloads\all products.csv')
sales_report_df = pd.read_excel(r'C:\Users\falve11887\Downloads\Sales Report DOSIsoft.xlsx', sheet_name='Data')
hierarchy_path = r'C:\Users\falve11887\OneDrive - Elekta\Documents\Monthly Clean up automations\products_hierarchy\DOSIsoft.json'

# Roda a função mágica
dosisoft_final = mu.generate_dosisoft_comparison_report(
    all_data=all_data_df, 
    sales_report=sales_report_df, 
    hierarchy_json_path=hierarchy_path,
    output_filename='DOSIsoft_Comparison_Report.xlsx'
)
# Out:
# Successfully generated: DOSIsoft_Comparison_Report.xlsx
